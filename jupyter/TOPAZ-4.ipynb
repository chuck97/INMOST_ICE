# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from netCDF4 import Dataset

# %%
data = xr.open_dataset('../../nc_topaz/dataset-ice.nc')

# %%
dt = Dataset('../../nc_topaz/dataset-ice.nc', 'r')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 24, x: 609, y: 881)
# Coordinates:
#     latitude       (y, x) float32 ...
#   * x              (x) float32 -38.0 -37.875 -37.75 ... 37.75 37.875 38.0
#   * y              (y) float32 -55.0 -54.875 -54.75 ... 54.75 54.875 55.0
#   * time           (time) datetime64[ns] 2016-04-13 ... 2016-04-13T23:00:00
#     longitude      (y, x) float32 ...
# Data variables:
#     uice           (time, y, x) float32 ...
#     vice           (time, y, x) float32 ...
#     ssh            (time, y, x) float32 ...
#     fice           (time, y, x) float32 ...
#     stereographic  int32 ...
#     hice           (time, y, x) float32 ...
#     u              (time, y, x) float32 ...
#     v              (time, y, x) float32 ...
# Attributes:
#     CDI:                             Climate Data Interface version 1.9.2 (ht...
#     Conventions:                     CF-1.4
#     title:                           Arctic Ocean Physics Analysis and Foreca...
# ...

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 24, x: 609, y: 881)
# Coordinates:
#     latitude       (y, x) float32 ...
#   * x              (x) float32 -38.0 -37.875 -37.75 ... 37.75 37.875 38.0
#   * y              (y) float32 -55.0 -54.875 -54.75 ... 54.75 54.875 55.0
#   * time           (time) datetime64[ns] 2016-04-13 ... 2016-04-13T23:00:00
#     longitude      (y, x) float32 ...
# Data variables:
#     uice           (time, y, x) float32 ...
#     vice           (time, y, x) float32 ...
#     ssh            (time, y, x) float32 ...
#     fice           (time, y, x) float32 ...
#     stereographic  int32 ...
#     hice           (time, y, x) float32 ...
#     u              (time, y, x) float32 ...
#     v              (time, y, x) float32 ...
# Attributes:
#     CDI:                             Climate Data Interface version 1.9.2 (ht...
#     Conventions:                     CF-1.4
#     title:                           Arctic Ocean Physics Analysis and Foreca...
# ...

# %%
data1 = xr.open_dataset('../Triangulation/Triangulation_thickening/concentration_data/seaice_conc_monthly_nh_f17_201003_v03r01.nc')
# Out:
# /home/chuck/.local/lib/python3.6/site-packages/xarray/conventions.py:500: SerializationWarning: variable 'melt_onset_day_seaice_conc_monthly_cdr' has multiple fill values {-1, 65535}, decoding all values to NaN.
#   decode_timedelta=decode_timedelta,

# %%
data1
# Out:
# <xarray.Dataset>
# Dimensions:                                 (time: 1, xgrid: 304, ygrid: 448)
# Coordinates:
#   * time                                    (time) datetime64[ns] 2010-03-01
#   * ygrid                                   (ygrid) float32 5837500.0 ... -53...
#   * xgrid                                   (xgrid) float32 -3837500.0 ... 37...
#     latitude                                (ygrid, xgrid) float64 ...
#     longitude                               (ygrid, xgrid) float64 ...
# Data variables:
#     projection                              |S1 ...
#     seaice_conc_monthly_cdr                 (time, ygrid, xgrid) float32 ...
#     stdev_of_seaice_conc_monthly_cdr        (time, ygrid, xgrid) float32 ...
#     melt_onset_day_seaice_conc_monthly_cdr  (time, ygrid, xgrid) float32 ...
#     qa_of_seaice_conc_monthly_cdr           (time, ygrid, xgrid) float32 ...
#     goddard_merged_seaice_conc_monthly      (time, ygrid, xgrid) float32 ...
# ...
