# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from netCDF4 import Dataset

# %%
data = xr.open_dataset('../../nc_topaz/dataset-ice.nc')

# %%
dt = Dataset('../../nc_topaz/dataset-ice.nc', 'r')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 24, x: 609, y: 881)
# Coordinates:
#     latitude       (y, x) float32 ...
#   * x              (x) float32 -38.0 -37.875 -37.75 ... 37.75 37.875 38.0
#   * y              (y) float32 -55.0 -54.875 -54.75 ... 54.75 54.875 55.0
#   * time           (time) datetime64[ns] 2016-04-13 ... 2016-04-13T23:00:00
#     longitude      (y, x) float32 ...
# Data variables:
#     uice           (time, y, x) float32 ...
#     vice           (time, y, x) float32 ...
#     ssh            (time, y, x) float32 ...
#     fice           (time, y, x) float32 ...
#     stereographic  int32 ...
#     hice           (time, y, x) float32 ...
#     u              (time, y, x) float32 ...
#     v              (time, y, x) float32 ...
# Attributes:
#     CDI:                             Climate Data Interface version 1.9.2 (ht...
#     Conventions:                     CF-1.4
#     title:                           Arctic Ocean Physics Analysis and Foreca...
# ...

# %%
print(dt.variables['latitude'][0][0])
print(dt.variables['longitude'][0][0])
print(dt.variables['x'][0])
print(dt.variables['y'][0])
# Out:
# 34.686497
# -79.640945
# -38.0
# -55.0
